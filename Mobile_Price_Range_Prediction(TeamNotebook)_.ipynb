# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit738767/Mobile-Price/blob/main/Mobile_Price_Range_Prediction(TeamNotebook)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the CSV file
mobile = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data_mobile_price_range.csv')

# %%
mobile.head()
# Out:
#    battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0            842     0          2.2  ...             0     1            1
# 1           1021     1          0.5  ...             1     0            2
# 2            563     1          0.5  ...             1     0            2
# 3            615     1          2.5  ...             0     0            2
# 4           1821     1          1.2  ...             1     0            1
#
# [5 rows x 21 columns]

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
mobile.describe()
# Out:
#        battery_power       blue  ...         wifi  price_range
# count    2000.000000  2000.0000  ...  2000.000000  2000.000000
# mean     1238.518500     0.4950  ...     0.507000     1.500000
# std       439.418206     0.5001  ...     0.500076     1.118314
# min       501.000000     0.0000  ...     0.000000     0.000000
# 25%       851.750000     0.0000  ...     0.000000     0.750000
# 50%      1226.000000     0.0000  ...     1.000000     1.500000
# 75%      1615.250000     1.0000  ...     1.000000     2.250000
# max      1998.000000     1.0000  ...     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
mobile.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
mobile.shape
# Out:
# (2000, 21)

# %% [markdown]
# # Handling Missing value

# %%
mobile.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# # First thing first  EDA

# %% [markdown]
# # What is the price range

# %%
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})
sns.distplot(
    mobile['price_range'], norm_hist=False, kde=False, bins=20, hist_kws={"alpha": 1}
).set(xlabel='price range', ylabel='Count');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # internal memory with price range

# %%
sns.pointplot(y="int_memory", x="price_range", data=mobile)

# %% [markdown]
# # Battery power with price range

# %%
fig = plt.figure(figsize=(9, 6))
ax = fig.gca()
mobile.boxplot(column = 'battery_power', by = 'price_range', ax = ax)
ax.set_ylabel("battery_power")
plt.show()

# %%
fig = plt.figure(figsize=(9, 6))
ax = fig.gca()
mobile.boxplot(column = 'clock_speed', by = 'price_range', ax = ax)
ax.set_ylabel("clock_speed")
plt.show()

# %% [markdown]
# # How does ram  is affected price

# %%
fig = plt.figure(figsize=(9, 6))
ax = fig.gca()
mobile.boxplot(column = 'ram', by = 'price_range', ax = ax)
ax.set_ylabel("ram")
plt.show()

# %% [markdown]
# # How many 3g support in mobile phone

# %%
labels = ["3G-supported",'Not supported']
values=mobile['three_g'].value_counts().values

# %%
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %% [markdown]
# # how many perecent of 4g support mobile phone

# %%
labels = ["4G-supported",'Not supported']
values=mobile['four_g'].value_counts().values

# %%
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %% [markdown]
# # Mobile weight vs price range

# %%
sns.jointplot(x='mobile_wt',y='price_range',data=mobile,kind='kde');

# %% [markdown]
# #Talk time vs Price range

# %%
sns.pointplot(y="talk_time", x="price_range", data=mobile)

# %% [markdown]
# # how many handset dual sim supported

# %%
labels = ["dualsim-supported",'Not supported']
values=mobile['dual_sim'].value_counts().values

# %%
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %% [markdown]
# # How many mobile phone has bluetooth support

# %%
labels = ["bluetooth-supported",'Not supported']
values=mobile['blue'].value_counts().values

# %%
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %% [markdown]
# # Number of phone with Front camera and primary camera

# %%
plt.figure(figsize=(10,6))
mobile['fc'].hist(alpha=0.5,color='blue',label='Front camera')
mobile['pc'].hist(alpha=0.5,color='red',label='Primary camera')
plt.legend()
plt.xlabel('MegaPixels')
# Out:
# Text(0.5, 0, 'MegaPixels')

# %% [markdown]
# # How many wifi supported in mobile

# %%
labels = ["wifi-supported",'Not supported']
values=mobile['wifi'].value_counts().values

# %%
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %% [markdown]
# # How many mobile has touchscreen

# %%
labels = ["touch-supported",'Not supported']
values=mobile['touch_screen'].value_counts().values

# %%
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %% [markdown]
# # Correlation between independent between dependent

# %%
plt.scatter(mobile['ram'], mobile['price_range'], alpha=0.5)
plt.title('Scatter plot of price_range with ram ')
plt.xlabel('ram')
plt.ylabel('price range')
plt.show()

# %%
plt.scatter(mobile['wifi'], mobile['price_range'], alpha=0.5)
plt.title('Scatter plot of price_range with wifi ')
plt.xlabel('wifi')
plt.ylabel('price range')
plt.show()

# %% [markdown]
# # Now the training part come

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from numpy import math

# %%
x=mobile.drop('price_range',axis=1)

# %%
y=mobile['price_range']

# %%
#splitting data into training and testing set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
#Logistic Regression
#training model
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)

#getting confusion matrix
from sklearn.metrics import confusion_matrix
y_pred_logi = lr.predict(x_test)
cm = confusion_matrix(y_test,y_pred_logi)
print('confusion matrix:\n',cm)

#checking accuracy
from sklearn.metrics import accuracy_score
lra = accuracy_score(y_test,y_pred_logi)
print('accuracy score = ',lra)
# Out:
# confusion matrix:
#  [[84 10  1  0]
#  [16 53 19  4]
#  [ 0 29 43 27]
#  [ 0  2 34 78]]
# accuracy score =  0.645
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
y_pred_train_logi = lr.predict(x_train)

# %%
# Vraiance Score for Logistic Regressor
print('Variance score for the Logistic Regressor raw is : %.2f' % lr.score(x_test, y_test))
# Out:
# Variance score for the Logistic Regressor raw is : 0.65

# %%
#knn
#training model
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski',p = 2)
knn.fit(x_train,y_train)

#getting confusion matrix
from sklearn.metrics import confusion_matrix
y_pred_knn = knn.predict(x_test)
cm = confusion_matrix(y_test,y_pred_knn)
print('confusion matrix:\n',cm)

#checking accuracy
from sklearn.metrics import accuracy_score
knna = accuracy_score(y_test,y_pred_knn)
print('accuracy score = ',accuracy_score(y_test,y_pred_knn))
# Out:
# confusion matrix:
#  [[ 92   3   0   0]
#  [  3  86   3   0]
#  [  0   6  85   8]
#  [  0   0   6 108]]
# accuracy score =  0.9275

# %%
y_pred_train_knn = knn.predict(x_train)

# %%
# Vraiance Score for K - Nearest Neighbour
print('Variance score for the KNN raw is : %.2f' % knn.score(x_test, y_test))
# Out:
# Variance score for the KNN raw is : 0.93

# %%
#SVM
#training model
from sklearn.svm import SVC
svc = SVC(kernel = 'linear',random_state = 0)
svc.fit(x_train,y_train)

#getting confusion matrix
from sklearn.metrics import confusion_matrix
y_pred_svc = svc.predict(x_test)
cm = confusion_matrix(y_test,y_pred_svc)
print('confusion matrix:\n',cm)

#checking accuracy
from sklearn.metrics import accuracy_score
sva =accuracy_score(y_test,y_pred_svc)
print('accuracy score = ',accuracy_score(y_test,y_pred_svc))
# Out:
# confusion matrix:
#  [[ 94   1   0   0]
#  [  0  89   3   0]
#  [  0   1  97   1]
#  [  0   0   3 111]]
# accuracy score =  0.9775

# %%
y_pred_train_svm = svc.predict(x_train)

# %%
# Vraiance Score For Support Vector Machine 
print('Variance score for the SVC raw is : %.2f' % svc.score(x_test, y_test))
# Out:
# Variance score for the SVC raw is : 0.98

# %%
#comparing accuracies
plt.figure(figsize= (8,7))
ac = [lra,knna,sva]
name = ['Logistic Regression','knn','svm']
sns.barplot(x = ac,y = name,palette='pastel')
plt.title("Plotting the Model Accuracies", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Plotting the Model Accuracies')

# %% [markdown]
# # Evaluation metrics

# %%
# R2 score of Logistic Train Performance
r2_score(y_train, y_pred_train_logi)
# Out:
# 0.6568013889449671

# %%
# R2 score of KNN Train Performance
r2_score(y_train, y_pred_train_knn)
# Out:
# 0.9535672467396132

# %%
# R2 score of SVM Train Performance
r2_score(y_train, y_pred_train_svm)
# Out:
# 0.9954576654419187

# %%
# Test Performance logistic regressor
r2_score(y_test , y_pred_logi)
# Out:
# 0.6837653267111594

# %%
# Test Performance KNN
r2_score(y_test , y_pred_knn)
# Out:
# 0.9437373894148688

# %%
# Test Performane SVM
r2_score(y_test , y_pred_svc)
# Out:
# 0.9825391898184076

# %% [markdown]
# # Conclusion:
# #After we analysis the mobile price range csv we see that in this dataset most of the phone has 3g supported the percentage is76.2  anf 4g has 52.1 so if you see the most of the phone has 3g, the ram has more important like in this dataset the ram is high so the price of mobile is also high ,battery life  is important for increase the mobile price in this dataset most in high price.We see that the svm give more accuracy
